# %%
from tensorflow import keras
from tensorflow.keras.layers import Input, Conv2D, Conv2DTranspose, Dense, Flatten, Reshape, BatchNormalization, GaussianNoise
from tensorflow.keras import Model, Sequential
from tensorflow.data import Dataset
import numpy as np
import matplotlib.pyplot as plt
import math
from tqdm import tqdm
import os

# %%
DATA_FILE = "x.npy"

batch_size = 32
codings_size = 384

# %% [markdown]
# ## Load Data
# Load data and split it into batches. Split into batches because the model(s) has/have a custom training loop and is trained one batch at a time so splitting the data now makes it a little easier later.

# %%
x = np.load(DATA_FILE)
img_shape = x.shape[1:]
batches = np.split(x[:len(x)//batch_size * batch_size], len(x)//batch_size)
del x

# %% [markdown]
# ## Define the Models

# %%
input_tensor = Input(shape=img_shape)

c1 = Conv2D(6, 5, strides=2, padding="same", activation='relu')
c2 = Conv2D(12, 3, strides=2, padding="same", activation='relu')
c3 = Conv2D(24, 3, strides=2, padding="same", activation='relu')
c4 = Conv2D(48, 3, strides=2, padding="same", activation='relu')
c5 = Conv2D(96, 3, strides=2, padding="same", activation='relu')
c6 = Conv2D(192, 3, strides=2, padding="same", activation='relu')
c7 = Conv2D(codings_size, 3, strides=2, padding="same", activation='relu')

bn1 = BatchNormalization()
bn2 = BatchNormalization()
bn3 = BatchNormalization()
bn4 = BatchNormalization()
bn5 = BatchNormalization()
bn6 = BatchNormalization()
bn7 = BatchNormalization()

ct1 = Conv2DTranspose(192, 3, strides=2, padding="same", activation='relu')
ct2 = Conv2DTranspose(96, 3, strides=2, padding="same", activation='relu')
ct3 = Conv2DTranspose(48, 3, strides=2, padding="same", activation='relu')
ct4 = Conv2DTranspose(24, 3, strides=2, padding="same", activation='relu')
ct5 = Conv2DTranspose(12, 3, strides=2, padding="same", activation='relu')
ct6 = Conv2DTranspose(6, 3, strides=2, padding="same", activation='relu')
ct7 = Conv2DTranspose(3, 3, strides=2, padding="same", activation='sigmoid')

# %%
# training_models = [
#     Sequential([input_tensor, c1, bn1, ct6]),
#     Sequential([input_tensor, c1, bn1, c2, bn2, ct5]),
#     Sequential([input_tensor, c1, bn1, c2, bn2, c3, bn3, ct4]),
#     Sequential([input_tensor, c1, bn1, c2, bn2, c3, bn3, c4, bn4, ct3]),
#     Sequential([input_tensor, c1, bn1, c2, bn2, c3, bn3, c4, bn4, c5, bn5, ct2]),
#     Sequential([input_tensor, c1, bn1, c2, bn2, c3, bn3, c4, bn4, c5, bn5, c6, bn6, ct1]),
# ]

training_models = [
    Sequential([input_tensor, c1, bn1, ct7]),
    Sequential([input_tensor, c1, bn1, c2, bn2, ct6]),
    Sequential([input_tensor, c1, bn1, c2, bn2, c3, bn3, ct5]),
    Sequential([input_tensor, c1, bn1, c2, bn2, c3, bn3, c4, bn4, ct4]),
    Sequential([input_tensor, c1, bn1, c2, bn2, c3, bn3, c4, bn4, c5, bn5, ct3]),
    Sequential([input_tensor, c1, bn1, c2, bn2, c3, bn3, c4, bn4, c5, bn5, c6, bn6, ct2]),
    Sequential([input_tensor, c1, bn1, c2, bn2, c3, bn3, c4, bn4, c5, bn5, c6, bn6, c7, bn7, ct1]),
]

targets = []

z = input_tensor
targets.append(z)
z = c1(z)
targets.append(z)
z = bn1(z)
z = c2(z)
targets.append(z)
z = bn2(z)
z = c3(z)
targets.append(z)
z = bn3(z)
z = c4(z)
targets.append(z)
z = bn4(z)
z = c5(z)
targets.append(z)
z = bn5(z)
z = c6(z)
targets.append(z)
z = bn6(z)
z = c7(z)
z = bn7(z)

for layer in [ct1, bn6, ct2, bn5, ct3, bn4, ct4, bn3, ct5, bn2, ct6, bn1, ct7]:
    z = layer(z)

output_tensor = z

for model in training_models:
    for layer in model.layers[:-3]:
        layer.trainable = False
    model.compile(optimizer="adam", loss="MSE", metrics=["mean_absolute_error"])
    model.summary()

target_model = Model(inputs=[input_tensor], outputs=targets)
inference_model = Model(inputs=[input_tensor], outputs=[z])

stacked_model = keras.models.clone_model(inference_model)
stacked_model.compile(optimizer="adam", loss="MSE", metrics=["mean_absolute_error"])
stacked_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 64, 64, 6)         456
# _________________________________________________________________
# batch_normalization (BatchNo (None, 64, 64, 6)         24
# _________________________________________________________________
# conv2d_transpose_6 (Conv2DTr (None, 128, 128, 3)       165
# =================================================================
# Total params: 645
# Trainable params: 633
# Non-trainable params: 12
# _________________________________________________________________
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 64, 64, 6)         456
# _________________________________________________________________
# batch_normalization (BatchNo (None, 64, 64, 6)         24
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 12)        660
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 32, 32, 12)        48
# _________________________________________________________________
# conv2d_transpose_5 (Conv2DTr (None, 64, 64, 6)         654
# =================================================================
# Total params: 1,842
# Trainable params: 1,338
# Non-trainable params: 504
# _________________________________________________________________
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 64, 64, 6)         456
# _________________________________________________________________
# batch_normalization (BatchNo (None, 64, 64, 6)         24
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 12)        660
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 32, 32, 12)        48
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 24)        2616
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 16, 16, 24)        96
# _________________________________________________________________
# conv2d_transpose_4 (Conv2DTr (None, 32, 32, 12)        2604
# =================================================================
# Total params: 6,504
# Trainable params: 5,268
# Non-trainable params: 1,236
# _________________________________________________________________
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 64, 64, 6)         456
# _________________________________________________________________
# batch_normalization (BatchNo (None, 64, 64, 6)         24
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 12)        660
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 32, 32, 12)        48
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 24)        2616
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 16, 16, 24)        96
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 8, 8, 48)          10416
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 8, 8, 48)          192
# _________________________________________________________________
# conv2d_transpose_3 (Conv2DTr (None, 16, 16, 24)        10392
# =================================================================
# Total params: 24,900
# Trainable params: 20,904
# Non-trainable params: 3,996
# _________________________________________________________________
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 64, 64, 6)         456
# _________________________________________________________________
# batch_normalization (BatchNo (None, 64, 64, 6)         24
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 12)        660
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 32, 32, 12)        48
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 24)        2616
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 16, 16, 24)        96
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 8, 8, 48)          10416
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 8, 8, 48)          192
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 4, 4, 96)          41568
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 4, 4, 96)          384
# _________________________________________________________________
# conv2d_transpose_2 (Conv2DTr (None, 8, 8, 48)          41520
# =================================================================
# Total params: 97,980
# Trainable params: 83,280
# Non-trainable params: 14,700
# _________________________________________________________________
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 64, 64, 6)         456
# _________________________________________________________________
# batch_normalization (BatchNo (None, 64, 64, 6)         24
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 12)        660
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 32, 32, 12)        48
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 24)        2616
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 16, 16, 24)        96
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 8, 8, 48)          10416
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 8, 8, 48)          192
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 4, 4, 96)          41568
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 4, 4, 96)          384
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 2, 2, 192)         166080
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 2, 2, 192)         768
# _________________________________________________________________
# conv2d_transpose_1 (Conv2DTr (None, 4, 4, 96)          165984
# =================================================================
# Total params: 389,292
# Trainable params: 332,448
# Non-trainable params: 56,844
# _________________________________________________________________
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 64, 64, 6)         456
# _________________________________________________________________
# batch_normalization (BatchNo (None, 64, 64, 6)         24
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 12)        660
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 32, 32, 12)        48
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 24)        2616
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 16, 16, 24)        96
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 8, 8, 48)          10416
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 8, 8, 48)          192
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 4, 4, 96)          41568
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 4, 4, 96)          384
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 2, 2, 192)         166080
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 2, 2, 192)         768
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 1, 1, 384)         663936
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 1, 1, 384)         1536
# _________________________________________________________________
# conv2d_transpose (Conv2DTran (None, 2, 2, 192)         663744
# =================================================================
# Total params: 1,552,524
# Trainable params: 1,328,448
# Non-trainable params: 224,076
# _________________________________________________________________
# Model: "functional_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 128, 128, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 64, 64, 6)    456         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 64, 64, 6)    24          conv2d[0][0]
#                                                                  conv2d_transpose_5[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 32, 32, 12)   660         batch_normalization[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 32, 32, 12)   48          conv2d_1[0][0]
#                                                                  conv2d_transpose_4[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 16, 16, 24)   2616        batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 16, 16, 24)   96          conv2d_2[0][0]
#                                                                  conv2d_transpose_3[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 8, 8, 48)     10416       batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 8, 8, 48)     192         conv2d_3[0][0]
#                                                                  conv2d_transpose_2[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 4, 4, 96)     41568       batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 4, 4, 96)     384         conv2d_4[0][0]
#                                                                  conv2d_transpose_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 2, 2, 192)    166080      batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 2, 2, 192)    768         conv2d_5[0][0]
#                                                                  conv2d_transpose[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 1, 1, 384)    663936      batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 1, 1, 384)    1536        conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 2, 2, 192)    663744      batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 4, 4, 96)     165984      batch_normalization_5[1][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 8, 8, 48)     41520       batch_normalization_4[1][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 16, 16, 24)   10392       batch_normalization_3[1][0]
# __________________________________________________________________________________________________
# conv2d_transpose_4 (Conv2DTrans (None, 32, 32, 12)   2604        batch_normalization_2[1][0]
# __________________________________________________________________________________________________
# conv2d_transpose_5 (Conv2DTrans (None, 64, 64, 6)    654         batch_normalization_1[1][0]
# __________________________________________________________________________________________________
# conv2d_transpose_6 (Conv2DTrans (None, 128, 128, 3)  165         batch_normalization[1][0]
# ==================================================================================================
# Total params: 1,773,843
# Trainable params: 1,549,767
# Non-trainable params: 224,076
# __________________________________________________________________________________________________

# %%
def train_step(batch):
    targets = target_model.predict(batch)

    for i, model in enumerate(training_models):
        model.train_on_batch(batch, targets[i])
    
    stacked_model.train_on_batch(batch, batch)

# inference_model = keras.models.load_model("inference.h5")
# stacked_model = keras.models.load_model("stacked.h5")

epochs = 10
for i in range(epochs):
    print("\nEpoch %d/%d" % (i, epochs))
    for batch in tqdm(batches):
        train_step(batch)
# Out:
#   0%|          | 0/413 [00:00<?, ?it/s]
# Epoch 0/10
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_train_function.<locals>.train_function at 0x7fb6d919d0d0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_train_function.<locals>.train_function at 0x7fb6d9133598> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:7 out of the last 7 calls to <function Model.make_train_function.<locals>.train_function at 0x7fb61c241158> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:8 out of the last 8 calls to <function Model.make_train_function.<locals>.train_function at 0x7fb6d8728d08> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 100%|██████████| 413/413 [01:55<00:00,  3.59it/s]
#   0%|          | 0/413 [00:00<?, ?it/s]
# Epoch 1/10
# 100%|██████████| 413/413 [01:49<00:00,  3.78it/s]
#   0%|          | 0/413 [00:00<?, ?it/s]
# Epoch 2/10
# 100%|██████████| 413/413 [01:49<00:00,  3.77it/s]
#   0%|          | 0/413 [00:00<?, ?it/s]
# Epoch 3/10
# 100%|██████████| 413/413 [01:48<00:00,  3.80it/s]
#   0%|          | 0/413 [00:00<?, ?it/s]
# Epoch 4/10
# 100%|██████████| 413/413 [01:49<00:00,  3.76it/s]
#   0%|          | 0/413 [00:00<?, ?it/s]
# Epoch 5/10
# 100%|██████████| 413/413 [01:49<00:00,  3.78it/s]
#   0%|          | 0/413 [00:00<?, ?it/s]
# Epoch 6/10
# 100%|██████████| 413/413 [01:49<00:00,  3.75it/s]
#   0%|          | 0/413 [00:00<?, ?it/s]
# Epoch 7/10
# 100%|██████████| 413/413 [01:49<00:00,  3.79it/s]
#   0%|          | 0/413 [00:00<?, ?it/s]
# Epoch 8/10
# 100%|██████████| 413/413 [01:50<00:00,  3.74it/s]
#   0%|          | 0/413 [00:00<?, ?it/s]
# Epoch 9/10
# 100%|██████████| 413/413 [01:48<00:00,  3.79it/s]

# %%
batches = np.array(batches)
B, N, _, _, _ = batches.shape
num_images = 5
batches_ind = np.random.randint(0, B, num_images)
imgs = np.random.randint(0, N, num_images)
display_images = batches[batches_ind, imgs, :, :, :]

reconstructions = inference_model.predict(display_images)
basic_reconstructions = stacked_model.predict(display_images)

fig, axs = plt.subplots(5, 3)

titles = ["Original", "Stacked", "Recursive"]

for r, row in enumerate(axs):
    imgs = [display_images[r], basic_reconstructions[r], reconstructions[r]]
    for c, ax in enumerate(row):
        img = imgs[c].astype(float)
        ax.imshow(img)
        if r == 0:
            ax.set_title(titles[c])

fig.set_size_inches(6, 9)
fig.savefig("faces.png")
fig.show()

# %%
inference_model.save("../models/relu_SB_R_7_384.h5")
stacked_model.save("../models/relu_SB_S_7_384.h5")
