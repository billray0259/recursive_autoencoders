# %%
from tensorflow import keras
from tensorflow.keras import backend as K
import tensorflow as tf
from tensorflow.keras.layers import Input, Conv2D, Conv2DTranspose, Dense, Flatten, Reshape, BatchNormalization, Layer
from tensorflow.keras import Model, Sequential
from tensorflow.data import Dataset
import numpy as np
import matplotlib.pyplot as plt
import math
from tqdm import tqdm
import os

# %%
DATA_FILE = "x.npy"

batch_size = 32
codings_size = 384

# %% [markdown]
# ## Load Data
# Load data and split it into batches. Split into batches because the model(s) has/have a custom training loop and is trained one batch at a time so splitting the data now makes it a little easier later.

# %%
x = np.load(DATA_FILE)
img_shape = x.shape[1:]
batches = np.split(x[:len(x)//batch_size * batch_size], len(x)//batch_size)
del x

# %% [markdown]
# ## Define sampling layer and variational block

# %%
# The code for this layer came from the HOML book by Geron
class Sampling(Layer):
    def call(self, inputs):
        mean, log_var = inputs
        return K.random_normal(tf.shape(log_var)) * K.exp(log_var / 2) + mean

keras.utils.get_custom_objects().update({"Sampling": Sampling})

# This was block heavily inspired by the HOML book
def add_variational_block(z):
    z = Flatten()(z)
    codings_mean = Dense(codings_size)(z)
    codings_log_var = Dense(codings_size)(z)
    codings = Sampling()((codings_mean, codings_log_var))
    z = Reshape((1, 1, codings_size))(codings)
    return z, codings_mean, codings_log_var

def latent_loss(codings_mean, codings_log_var):
    latent_loss = -0.5 * K.sum(1 + codings_log_var - K.exp(codings_log_var) - K.square(codings_mean), axis=-1)
    return K.mean(latent_loss) / (img_shape[-1]*img_shape[-2])

# input_tensor = Input(shape=(1, 1, codings_size))
# z = input_tensor
# z = Flatten()(z)
# codings_mean = Dense(codings_size)(z)
# codings_log_var = Dense(codings_size)(z)
# codings = Sampling()((codings_mean, codings_log_var))
# output_tensor = Reshape((1, 1, codings_size))(codings)
# variational_block = Model(inputs=[input_tensor], outputs=[output_tensor])

# %% [markdown]
# ## Define the Models

# %%
input_tensor = Input(shape=img_shape)

c1 = Conv2D(6, 5, strides=2, padding="same", activation='selu')
c2 = Conv2D(12, 3, strides=2, padding="same", activation='selu')
c3 = Conv2D(24, 3, strides=2, padding="same", activation='selu')
c4 = Conv2D(48, 3, strides=2, padding="same", activation='selu')
c5 = Conv2D(96, 3, strides=2, padding="same", activation='selu')
c6 = Conv2D(192, 3, strides=2, padding="same", activation='selu')
c7 = Conv2D(codings_size, 3, strides=2, padding="same", activation='selu')

bn1 = BatchNormalization()
bn2 = BatchNormalization()
bn3 = BatchNormalization()
bn4 = BatchNormalization()
bn5 = BatchNormalization()
bn6 = BatchNormalization()

ct1 = Conv2DTranspose(192, 3, strides=2, padding="same", activation='selu')
ct2 = Conv2DTranspose(96, 3, strides=2, padding="same", activation='selu')
ct3 = Conv2DTranspose(48, 3, strides=2, padding="same", activation='selu')
ct4 = Conv2DTranspose(24, 3, strides=2, padding="same", activation='selu')
ct5 = Conv2DTranspose(12, 3, strides=2, padding="same", activation='selu')
ct6 = Conv2DTranspose(6, 3, strides=2, padding="same", activation='selu')
ct7 = Conv2DTranspose(3, 3, strides=2, padding="same", activation='sigmoid')

# %%
training_models = [
    Sequential([input_tensor, c1, bn1, ct7]),
    Sequential([input_tensor, c1, bn1, c2, bn2, ct6]),
    Sequential([input_tensor, c1, bn1, c2, bn2, c3, bn3, ct5]),
    Sequential([input_tensor, c1, bn1, c2, bn2, c3, bn3, c4, bn4, ct4]),
    Sequential([input_tensor, c1, bn1, c2, bn2, c3, bn3, c4, bn4, c5, bn5, ct3]),
    Sequential([input_tensor, c1, bn1, c2, bn2, c3, bn3, c4, bn4, c5, bn5, c6, bn6, ct2]),
    # Sequential([input_tensor, c1, bn1, c2, bn2, c3, bn3, c4, bn4, c5, bn5, c6, bn6, c7, variational_block, ct1]),
]

z = input_tensor
for layer in [c1, bn1, c2, bn2, c3, bn3, c4, bn4, c5, bn5, c6, bn6, c7]:
    z = layer(z)
z, codings_mean_intermediate, codings_log_var_intermediate = add_variational_block(z)
output_tensor = ct1(z)

last_training_model = Model(inputs=[input_tensor], outputs=[output_tensor])
last_training_model.add_loss(latent_loss(codings_mean_intermediate, codings_log_var_intermediate))

training_models.append(last_training_model)

targets = []

z = input_tensor
targets.append(z)
z = c1(z)
targets.append(z)
z = bn1(z)
z = c2(z)
targets.append(z)
z = bn2(z)
z = c3(z)
targets.append(z)
z = bn3(z)
z = c4(z)
targets.append(z)
z = bn4(z)
z = c5(z)
targets.append(z)
z = bn5(z)
z = c6(z)
targets.append(z)
z = bn6(z)
z = c7(z)

z, codings_mean, codings_log_var = add_variational_block(z)

for layer in [ct1, bn6, ct2, bn5, ct3, bn4, ct4, bn3, ct5, bn2, ct6, bn1, ct7]:
    z = layer(z)

output_tensor = z

for model in training_models:
    for layer in model.layers[:-3]:
        layer.trainable = False
    model.compile(optimizer="adam", loss="MSE", metrics=["mean_absolute_error"])

# model = training_models[-1]
# for layer in model.layers[:-3]:
#         layer.trainable = False

target_model = Model(inputs=[input_tensor], outputs=targets)
inference_model = Model(inputs=[input_tensor], outputs=[output_tensor])

training_models[0].summary()
training_models[-1].summary()
inference_model.summary()

# stacked_model = keras.models.clone_model(inference_model)
# stacked_model.add_loss(latent_loss(codings_mean, codings_log_var))
# stacked_model.compile(optimizer="adam", loss="MSE", metrics=["mean_absolute_error"])
# stacked_model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_7 (Conv2D)            (None, 64, 64, 6)         456
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 64, 64, 6)         24
# _________________________________________________________________
# conv2d_transpose_13 (Conv2DT (None, 128, 128, 3)       165
# =================================================================
# Total params: 645
# Trainable params: 165
# Non-trainable params: 480
# _________________________________________________________________
# Model: "functional_7"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 128, 128, 3) 0
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 64, 64, 6)    456         input_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 64, 64, 6)    24          conv2d_7[6][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 32, 32, 12)   660         batch_normalization_6[6][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 32, 32, 12)   48          conv2d_8[5][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 16, 16, 24)   2616        batch_normalization_7[5][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 16, 16, 24)   96          conv2d_9[4][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 8, 8, 48)     10416       batch_normalization_8[4][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 8, 8, 48)     192         conv2d_10[3][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 4, 4, 96)     41568       batch_normalization_9[3][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 4, 4, 96)     384         conv2d_11[2][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 2, 2, 192)    166080      batch_normalization_10[2][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 2, 2, 192)    768         conv2d_12[1][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 1, 1, 384)    663936      batch_normalization_11[1][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 384)          0           conv2d_13[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 384)          147840      flatten_2[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 384)          147840      flatten_2[0][0]
# __________________________________________________________________________________________________
# sampling_2 (Sampling)           (None, 384)          0           dense_4[0][0]
#                                                                  dense_5[0][0]
# __________________________________________________________________________________________________
# reshape_2 (Reshape)             (None, 1, 1, 384)    0           sampling_2[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_7 (Conv2DTrans (None, 2, 2, 192)    663744      reshape_2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_1 (TensorFlow [(None, 384)]        0           dense_5[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Exp_1 (TensorFlowOp [(None, 384)]        0           dense_5[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sub_2 (TensorFlowOp [(None, 384)]        0           tf_op_layer_AddV2_1[0][0]
#                                                                  tf_op_layer_Exp_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Square_1 (TensorFlo [(None, 384)]        0           dense_4[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sub_3 (TensorFlowOp [(None, 384)]        0           tf_op_layer_Sub_2[0][0]
#                                                                  tf_op_layer_Square_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sum_1 (TensorFlowOp [(None,)]            0           tf_op_layer_Sub_3[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mul_1 (TensorFlowOp [(None,)]            0           tf_op_layer_Sum_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mean_1 (TensorFlowO [()]                 0           tf_op_layer_Mul_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_RealDiv_1 (TensorFl [()]                 0           tf_op_layer_Mean_1[0][0]
# __________________________________________________________________________________________________
# add_loss_1 (AddLoss)            ()                   0           tf_op_layer_RealDiv_1[0][0]
# ==================================================================================================
# Total params: 1,846,668
# Trainable params: 0
# Non-trainable params: 1,846,668
# __________________________________________________________________________________________________
# Model: "functional_11"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 128, 128, 3) 0
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 64, 64, 6)    456         input_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 64, 64, 6)    24          conv2d_7[7][0]
#                                                                  conv2d_transpose_12[1][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 32, 32, 12)   660         batch_normalization_6[7][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 32, 32, 12)   48          conv2d_8[6][0]
#                                                                  conv2d_transpose_11[1][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 16, 16, 24)   2616        batch_normalization_7[6][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 16, 16, 24)   96          conv2d_9[5][0]
#                                                                  conv2d_transpose_10[1][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 8, 8, 48)     10416       batch_normalization_8[5][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 8, 8, 48)     192         conv2d_10[4][0]
#                                                                  conv2d_transpose_9[1][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 4, 4, 96)     41568       batch_normalization_9[4][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 4, 4, 96)     384         conv2d_11[3][0]
#                                                                  conv2d_transpose_8[1][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 2, 2, 192)    166080      batch_normalization_10[3][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 2, 2, 192)    768         conv2d_12[2][0]
#                                                                  conv2d_transpose_7[1][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 1, 1, 384)    663936      batch_normalization_11[2][0]
# __________________________________________________________________________________________________
# flatten_3 (Flatten)             (None, 384)          0           conv2d_13[1][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 384)          147840      flatten_3[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 384)          147840      flatten_3[0][0]
# __________________________________________________________________________________________________
# sampling_3 (Sampling)           (None, 384)          0           dense_6[0][0]
#                                                                  dense_7[0][0]
# __________________________________________________________________________________________________
# reshape_3 (Reshape)             (None, 1, 1, 384)    0           sampling_3[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_7 (Conv2DTrans (None, 2, 2, 192)    663744      reshape_3[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_8 (Conv2DTrans (None, 4, 4, 96)     165984      batch_normalization_11[3][0]
# __________________________________________________________________________________________________
# conv2d_transpose_9 (Conv2DTrans (None, 8, 8, 48)     41520       batch_normalization_10[4][0]
# __________________________________________________________________________________________________
# conv2d_transpose_10 (Conv2DTran (None, 16, 16, 24)   10392       batch_normalization_9[5][0]
# __________________________________________________________________________________________________
# conv2d_transpose_11 (Conv2DTran (None, 32, 32, 12)   2604        batch_normalization_8[6][0]
# __________________________________________________________________________________________________
# conv2d_transpose_12 (Conv2DTran (None, 64, 64, 6)    654         batch_normalization_7[7][0]
# __________________________________________________________________________________________________
# conv2d_transpose_13 (Conv2DTran (None, 128, 128, 3)  165         batch_normalization_6[8][0]
# ==================================================================================================
# Total params: 2,067,987
# Trainable params: 516,999
# Non-trainable params: 1,550,988
# __________________________________________________________________________________________________

# %%
def train_step(batch):
    targets = target_model.predict(batch)

    for i, model in enumerate(training_models):
        model.train_on_batch(batch, targets[i])
    
    # stacked_model.train_on_batch(batch, batch)

# inference_model = keras.models.load_model("inference.h5")
# stacked_model = keras.models.load_model("stacked.h5")

epochs = 10
for i in range(epochs):
    print("\nEpoch %d/%d" % (i, epochs))
    for batch in tqdm(batches):
        train_step(batch)

# %%
inference_model.save("var_inference.h5")
# stacked_model.save("var_stacked.h5")

# %%
batches = np.array(batches)
B, N, _, _, _ = batches.shape
num_images = 5
batches_ind = np.random.randint(0, B, num_images)
imgs = np.random.randint(0, N, num_images)
display_images = batches[batches_ind, imgs, :, :, :]

reconstructions = inference_model.predict(display_images)
# basic_reconstructions = stacked_model.predict(display_images)
basic_reconstructions = display_images

fig, axs = plt.subplots(5, 3)

titles = ["Original", "Stacked", "Recursive"]

for r, row in enumerate(axs):
    imgs = [display_images[r], basic_reconstructions[r], reconstructions[r]]
    for c, ax in enumerate(row):
        img = imgs[c].astype(float)
        ax.imshow(img)
        if r == 0:
            ax.set_title(titles[c])

fig.set_size_inches(6, 9)
fig.savefig("faces.png")
fig.show()
